# %% [markdown]
# # Data Overview
# _Author : Benjamin Ternot_

# %% [markdown]
# ## Pip installs just in case

# %%
#pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.3-cp311-cp311-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.2.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 7.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.0 MB 7.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 7.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 6.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.8/2.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp311-cp311-win_amd64.whl (56 kB)
# Downloading numpy-2.2.0-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.9 MB 7.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.9 MB 7.2 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.9 MB 7.2 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/12.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.9 MB 7.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 6.6 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------------------ --------------- 1.6/2.6 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 7.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.7 matplotlib-3.10.0 numpy-2.2.0 pillow-11.0.0 pyparsing-3.2.0

# %%
#pip install scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_learn-1.6.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.0-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.1 MB 7.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/11.1 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.1 MB 7.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.1 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 7.2 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    - -------------------------------------- 1.6/44.8 MB 8.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.4/44.8 MB 7.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/44.8 MB 7.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.6/44.8 MB 7.5 MB/s eta 0:00:06
#    ------- -------------------------------- 8.1/44.8 MB 7.5 MB/s eta 0:00:05
#    -------- ------------------------------- 9.7/44.8 MB 7.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 11.3/44.8 MB 7.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.8/44.8 MB 7.5 MB/s eta 0:00:05
#    ------------- -------------------------- 14.7/44.8 MB 7.5 MB/s eta 0:00:05
#    -------------- ------------------------- 16.3/44.8 MB 7.5 MB/s eta 0:00:04
#    --------------- ------------------------ 17.8/44.8 MB 7.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 19.4/44.8 MB 7.5 MB/s eta 0:00:04
#    ------------------ --------------------- 21.2/44.8 MB 7.5 MB/s eta 0:00:04
#    -------------------- ------------------- 22.5/44.8 MB 7.3 MB/s eta 0:00:04
#    --------------------- ------------------ 24.4/44.8 MB 7.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.2/44.8 MB 7.3 MB/s eta 0:00:03
#    ------------------------ --------------- 27.8/44.8 MB 7.3 MB/s eta 0:00:03
#    -------------------------- ------------- 29.4/44.8 MB 7.3 MB/s eta 0:00:03
#    --------------------------- ------------ 30.9/44.8 MB 7.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.8/44.8 MB 7.4 MB/s eta 0:00:02
#    ------------------------------ --------- 34.3/44.8 MB 7.3 MB/s eta 0:00:02
#    -------------------------------- ------- 35.9/44.8 MB 7.3 MB/s eta 0:00:02
#    --------------------------------- ------ 38.0/44.8 MB 7.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.6/44.8 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 41.4/44.8 MB 7.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/44.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 7.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.0 scipy-1.14.1 threadpoolctl-3.5.0

# %%
#pip install torch
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting torch
#   Downloading torch-2.5.1-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Downloading torch-2.5.1-cp311-cp311-win_amd64.whl (203.1 MB)
#    ---------------------------------------- 0.0/203.1 MB ? eta -:--:--
#    ---------------------------------------- 1.3/203.1 MB 6.7 MB/s eta 0:00:31
#     --------------------------------------- 2.9/203.1 MB 7.0 MB/s eta 0:00:29
#     --------------------------------------- 4.2/203.1 MB 7.0 MB/s eta 0:00:29
#    - -------------------------------------- 5.8/203.1 MB 7.0 MB/s eta 0:00:29
#    - -------------------------------------- 7.3/203.1 MB 7.1 MB/s eta 0:00:28
#    - -------------------------------------- 8.9/203.1 MB 7.1 MB/s eta 0:00:28
#    -- ------------------------------------- 10.7/203.1 MB 7.1 MB/s eta 0:00:28
#    -- ------------------------------------- 12.3/203.1 MB 7.1 MB/s eta 0:00:27
#    -- ------------------------------------- 13.9/203.1 MB 7.1 MB/s eta 0:00:27
#    -- ------------------------------------- 15.2/203.1 MB 7.1 MB/s eta 0:00:27
#    --- ------------------------------------ 16.8/203.1 MB 7.1 MB/s eta 0:00:27
#    --- ------------------------------------ 18.4/203.1 MB 7.1 MB/s eta 0:00:27
#    --- ------------------------------------ 19.7/203.1 MB 7.1 MB/s eta 0:00:27
#    ---- ----------------------------------- 21.2/203.1 MB 7.1 MB/s eta 0:00:26
#    ---- ----------------------------------- 22.8/203.1 MB 7.1 MB/s eta 0:00:26
#    ---- ----------------------------------- 24.4/203.1 MB 7.1 MB/s eta 0:00:26
#    ----- ---------------------------------- 26.2/203.1 MB 7.1 MB/s eta 0:00:25
#    ----- ---------------------------------- 27.8/203.1 MB 7.1 MB/s eta 0:00:25
#    ----- ---------------------------------- 29.4/203.1 MB 7.2 MB/s eta 0:00:25
#    ------ --------------------------------- 30.9/203.1 MB 7.2 MB/s eta 0:00:25
#    ------ --------------------------------- 33.0/203.1 MB 7.2 MB/s eta 0:00:24
#    ------ --------------------------------- 34.6/203.1 MB 7.2 MB/s eta 0:00:24
#    ------- -------------------------------- 36.4/203.1 MB 7.2 MB/s eta 0:00:24
#    ------- -------------------------------- 38.0/203.1 MB 7.2 MB/s eta 0:00:23
#    ------- -------------------------------- 39.8/203.1 MB 7.2 MB/s eta 0:00:23
#    -------- ------------------------------- 41.4/203.1 MB 7.3 MB/s eta 0:00:23
#    -------- ------------------------------- 43.3/203.1 MB 7.3 MB/s eta 0:00:23
#    -------- ------------------------------- 44.8/203.1 MB 7.3 MB/s eta 0:00:22
#    --------- ------------------------------ 46.4/203.1 MB 7.3 MB/s eta 0:00:22
#    --------- ------------------------------ 48.0/203.1 MB 7.3 MB/s eta 0:00:22
#    --------- ------------------------------ 49.0/203.1 MB 7.2 MB/s eta 0:00:22
#    ---------- ----------------------------- 50.9/203.1 MB 7.2 MB/s eta 0:00:22
#    ---------- ----------------------------- 52.4/203.1 MB 7.2 MB/s eta 0:00:21
#    ---------- ----------------------------- 54.0/203.1 MB 7.2 MB/s eta 0:00:21
#    ---------- ----------------------------- 55.6/203.1 MB 7.2 MB/s eta 0:00:21
#    ----------- ---------------------------- 57.1/203.1 MB 7.3 MB/s eta 0:00:21
#    ----------- ---------------------------- 59.0/203.1 MB 7.3 MB/s eta 0:00:20
#    ----------- ---------------------------- 60.6/203.1 MB 7.3 MB/s eta 0:00:20
#    ------------ --------------------------- 62.1/203.1 MB 7.3 MB/s eta 0:00:20
#    ------------ --------------------------- 62.9/203.1 MB 7.3 MB/s eta 0:00:20
#    ------------ --------------------------- 64.7/203.1 MB 7.2 MB/s eta 0:00:20
#    ------------- -------------------------- 66.3/203.1 MB 7.2 MB/s eta 0:00:19
#    ------------- -------------------------- 67.9/203.1 MB 7.2 MB/s eta 0:00:19
#    ------------- -------------------------- 69.5/203.1 MB 7.2 MB/s eta 0:00:19
#    -------------- ------------------------- 71.3/203.1 MB 7.2 MB/s eta 0:00:19
#    -------------- ------------------------- 72.9/203.1 MB 7.2 MB/s eta 0:00:18
#    -------------- ------------------------- 74.4/203.1 MB 7.3 MB/s eta 0:00:18
#    -------------- ------------------------- 76.0/203.1 MB 7.3 MB/s eta 0:00:18
#    --------------- ------------------------ 77.9/203.1 MB 7.3 MB/s eta 0:00:18
#    --------------- ------------------------ 79.4/203.1 MB 7.3 MB/s eta 0:00:17
#    --------------- ------------------------ 81.0/203.1 MB 7.3 MB/s eta 0:00:17
#    ---------------- ----------------------- 82.8/203.1 MB 7.3 MB/s eta 0:00:17
#    ---------------- ----------------------- 84.4/203.1 MB 7.3 MB/s eta 0:00:17
#    ---------------- ----------------------- 86.0/203.1 MB 7.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 87.8/203.1 MB 7.3 MB/s eta 0:00:16
#    ----------------- ---------------------- 89.4/203.1 MB 7.3 MB/s eta 0:00:16
#    ----------------- ---------------------- 91.0/203.1 MB 7.3 MB/s eta 0:00:16
#    ------------------ --------------------- 92.8/203.1 MB 7.3 MB/s eta 0:00:16
#    ------------------ --------------------- 94.4/203.1 MB 7.3 MB/s eta 0:00:15
#    ------------------ --------------------- 95.9/203.1 MB 7.4 MB/s eta 0:00:15
#    ------------------- -------------------- 97.8/203.1 MB 7.4 MB/s eta 0:00:15
#    ------------------- -------------------- 99.4/203.1 MB 7.4 MB/s eta 0:00:15
#    ------------------- -------------------- 100.9/203.1 MB 7.4 MB/s eta 0:00:14
#    -------------------- ------------------- 102.8/203.1 MB 7.4 MB/s eta 0:00:14
#    -------------------- ------------------- 104.3/203.1 MB 7.4 MB/s eta 0:00:14
#    -------------------- ------------------- 105.9/203.1 MB 7.4 MB/s eta 0:00:14
#    --------------------- ------------------ 107.7/203.1 MB 7.4 MB/s eta 0:00:13
#    --------------------- ------------------ 109.3/203.1 MB 7.4 MB/s eta 0:00:13
#    --------------------- ------------------ 110.9/203.1 MB 7.4 MB/s eta 0:00:13
#    ---------------------- ----------------- 112.7/203.1 MB 7.4 MB/s eta 0:00:13
#    ---------------------- ----------------- 114.3/203.1 MB 7.4 MB/s eta 0:00:12
#    ---------------------- ----------------- 116.1/203.1 MB 7.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 117.7/203.1 MB 7.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 119.0/203.1 MB 7.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 120.6/203.1 MB 7.4 MB/s eta 0:00:12
#    ------------------------ --------------- 122.2/203.1 MB 7.4 MB/s eta 0:00:11
#    ------------------------ --------------- 124.0/203.1 MB 7.4 MB/s eta 0:00:11
#    ------------------------ --------------- 125.6/203.1 MB 7.4 MB/s eta 0:00:11
#    ------------------------- -------------- 127.1/203.1 MB 7.4 MB/s eta 0:00:11
#    ------------------------- -------------- 128.7/203.1 MB 7.4 MB/s eta 0:00:11
#    ------------------------- -------------- 130.8/203.1 MB 7.4 MB/s eta 0:00:10
#    -------------------------- ------------- 132.4/203.1 MB 7.4 MB/s eta 0:00:10
#    -------------------------- ------------- 134.0/203.1 MB 7.4 MB/s eta 0:00:10
#    -------------------------- ------------- 135.5/203.1 MB 7.4 MB/s eta 0:00:10
#    --------------------------- ------------ 137.4/203.1 MB 7.4 MB/s eta 0:00:09
#    --------------------------- ------------ 138.9/203.1 MB 7.4 MB/s eta 0:00:09
#    --------------------------- ------------ 140.5/203.1 MB 7.4 MB/s eta 0:00:09
#    ---------------------------- ----------- 142.3/203.1 MB 7.4 MB/s eta 0:00:09
#    ---------------------------- ----------- 143.9/203.1 MB 7.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 145.5/203.1 MB 7.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 147.1/203.1 MB 7.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 148.9/203.1 MB 7.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 150.5/203.1 MB 7.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 152.0/203.1 MB 7.4 MB/s eta 0:00:07
#    ------------------------------ --------- 153.6/203.1 MB 7.4 MB/s eta 0:00:07
#    ------------------------------ --------- 155.5/203.1 MB 7.4 MB/s eta 0:00:07
#    ------------------------------ --------- 157.0/203.1 MB 7.4 MB/s eta 0:00:07
#    ------------------------------- -------- 158.9/203.1 MB 7.4 MB/s eta 0:00:06
#    ------------------------------- -------- 160.4/203.1 MB 7.4 MB/s eta 0:00:06
#    ------------------------------- -------- 162.3/203.1 MB 7.4 MB/s eta 0:00:06
#    -------------------------------- ------- 163.8/203.1 MB 7.4 MB/s eta 0:00:06
#    -------------------------------- ------- 165.7/203.1 MB 7.4 MB/s eta 0:00:06
#    -------------------------------- ------- 167.2/203.1 MB 7.4 MB/s eta 0:00:05
#    --------------------------------- ------ 168.8/203.1 MB 7.4 MB/s eta 0:00:05
#    --------------------------------- ------ 170.4/203.1 MB 7.4 MB/s eta 0:00:05
#    --------------------------------- ------ 172.2/203.1 MB 7.4 MB/s eta 0:00:05
#    ---------------------------------- ----- 173.8/203.1 MB 7.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 175.4/203.1 MB 7.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 176.9/203.1 MB 7.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 178.8/203.1 MB 7.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 180.4/203.1 MB 7.5 MB/s eta 0:00:04
#    ----------------------------------- ---- 181.9/203.1 MB 7.4 MB/s eta 0:00:03
#    ------------------------------------ --- 183.5/203.1 MB 7.4 MB/s eta 0:00:03
#    ------------------------------------ --- 185.1/203.1 MB 7.4 MB/s eta 0:00:03
#    ------------------------------------ --- 186.6/203.1 MB 7.4 MB/s eta 0:00:03
#    ------------------------------------- -- 188.2/203.1 MB 7.4 MB/s eta 0:00:02
#    ------------------------------------- -- 189.5/203.1 MB 7.4 MB/s eta 0:00:02
#    ------------------------------------- -- 191.1/203.1 MB 7.4 MB/s eta 0:00:02
#    ------------------------------------- -- 192.9/203.1 MB 7.4 MB/s eta 0:00:02
#    -------------------------------------- - 194.5/203.1 MB 7.4 MB/s eta 0:00:02
#    -------------------------------------- - 196.1/203.1 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 197.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  199.5/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  201.1/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 203.1/203.1 MB 6.9 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.3/6.2 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 6.5 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.8 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch
# Successfully installed MarkupSafe-3.0.2 filelock-3.16.1 fsspec-2024.10.0 jinja2-3.1.4 mpmath-1.3.0 networkx-3.4.2 sympy-1.13.1 torch-2.5.1

# %%
#pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchmetrics) (2.2.0)
# Requirement already satisfied: packaging>17.1 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchmetrics) (2.5.1)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ---------------------------------------- 0.0/926.4 kB ? eta -:--:--
#    ---------------------------------------- 926.4/926.4 kB 5.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install torchvision
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting torchvision
#   Downloading torchvision-0.20.1-cp311-cp311-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchvision) (2.2.0)
# Requirement already satisfied: torch==2.5.1 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
# Downloading torchvision-0.20.1-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --------------------------------- ------ 1.3/1.6 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.2 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.20.1

# %%
#pip install tdqm
# Out:
# Collecting tdqmNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tdqm-0.0.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tqdm (from tdqm)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from tqdm->tdqm) (0.4.6)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Building wheels for collected packages: tdqm
#   Building wheel for tdqm (setup.py): started
#   Building wheel for tdqm (setup.py): finished with status 'done'
#   Created wheel for tdqm: filename=tdqm-0.0.1-py3-none-any.whl size=1333 sha256=2599cb540d55aa8a7f06fc83e823e6708a5403752f0fec03e91e4fe776e9cc53
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\c8\c7\30\e5935be2cfa6883be72462333edc414d8928f3c78eaabec38a
# Successfully built tdqm
# Installing collected packages: tqdm, tdqm
# Successfully installed tdqm-0.0.1 tqdm-4.67.1

# %%
#pip install nibabel
# Out:
# Collecting nibabelNote: you may need to restart the kernel to use updated packages.
#
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting importlib-resources>=5.12 (from nibabel)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from nibabel) (2.2.0)
# Requirement already satisfied: packaging>=20 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from nibabel) (4.12.2)
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --------------- ------------------------ 1.3/3.3 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 3.1/3.3 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 6.5 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Installing collected packages: importlib-resources, nibabel
# Successfully installed importlib-resources-6.4.5 nibabel-5.3.2

# %%
#pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.6 MB 7.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.6 MB 7.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.6 MB 7.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 6.9 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2

# %%
#pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
# Installing collected packages: einops
# Successfully installed einops-0.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install opencv-python
# Out:
#   Cell In[5], line 2
#     pip install einops
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Importing Libraries and Global Settings

# %%
import os
import gc
import datetime
import random

import sklearn

import IPython

import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import torch
from torch import nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import DataLoader as TorchDataLoader, random_split
from torchmetrics.image.fid import FrechetInceptionDistance
from torchvision.transforms import ToPILImage
from torchvision.utils import make_grid
from tqdm.notebook import tqdm

from data_manager.datamanager import *
from models.model import Unet

from ControlNet.acdcloader import * 
from ControlNet.ControledUNet import * 
from ControlNet.ControledUNet import * 
from ControlNet.Copy_weights import * 
from ControlNet.Full_Model import * 
from ControlNet.util import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 26
#      23 from data_manager.datamanager import *
#      24 from models.model import Unet
# ---> 26 from ControlNet.acdcloader import *
#      27 from ControlNet.ControledUNet import *
#      28 from ControlNet.ControledUNet import *
#
# File c:\Users\louis\Documents\PRIM\PRIM-AI-Diffusion-Models-for-Cardiac-Images-main\PRIM-AI-Diffusion-Models-for-Cardiac-Images-main\src\ControlNet\acdcloader.py:11
#       8 from torch.utils.data import Dataset, DataLoader
#       9 from tqdm.notebook import tqdm
# ---> 11 from guided_diffusion.utils import VerboseLevel
#      14 class ACDCDataset(Dataset):
#      15     def __init__(self, data_path, transform=None, mode='training', verbose: VerboseLevel=VerboseLevel.TQDM):
#
# ModuleNotFoundError: No module named 'guided_diffusion'

# %%
IMAGE_SIZE = 64

LIBERATE_MEMORY = True # Delete intermediate object to free memory space

TRAIN_MODEL = True
SAVE_MODEL = True
LOAD_MODEL = not TRAIN_MODEL
MODEL_LOAD_PATH = "models/trained_models/"


TRAIN_FULL_MODEL = True
SAVE_FULL_MODEL = True
LOAD_FULL_MODEL = not TRAIN_MODEL
FULL_MODEL_LOAD_PATH = "models/trained_models/"

MULTI_CHANNEL = True
BATCH_SIZE = 16
EPOCHS = 100
T = 1000
DIM_MULTS = (1, 2, 4)

# %%
# Modifier les couleurs des textes et des axes en fonction du thème de Jupyter
DARK_BG = False

if DARK_BG:
    plt.rcParams['text.color'] = 'white'
    plt.rcParams['axes.labelcolor'] = 'white'
    plt.rcParams['xtick.color'] = 'white'
    plt.rcParams['ytick.color'] = 'white'
    plt.rcParams['axes.titlecolor'] = 'white'
else:
    plt.rcParams['text.color'] = 'black'
    plt.rcParams['axes.labelcolor'] = 'black'
    plt.rcParams['xtick.color'] = 'black'
    plt.rcParams['ytick.color'] = 'black'
    plt.rcParams['axes.titlecolor'] = 'black'

# %%
current_datetime = datetime.datetime.now()
SAVE_PATH = f"images/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + '4-channels' if MULTI_CHANNEL else '1-channel'
MODEL_SAVE_PATH = f"models/trained_models/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + ('4-channels' if MULTI_CHANNEL else '1-channel') + "_trained-unet.pt"
MODEL_BEST_SAVE_PATH = f"models/trained_models/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + ('4-channels' if MULTI_CHANNEL else '1-channel') + "_best-trained-unet.pt"
PARAMS_SAVE_PATH = f"models/trained_models/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + ('4-channels' if MULTI_CHANNEL else '1-channel') + "_params.txt"
INPUT_SAVE_PATH = SAVE_PATH + "_batch_input.jpg"
OUTPUT_LOSS_MONITORING_PATH = SAVE_PATH + "_loss_monitoring.jpg"
OUTPUT_SAVE_PATH = SAVE_PATH + "_sampling.jpg"
OUTPUT_ONE_HOT_SAVE_PATH = SAVE_PATH + "_sampling_one-hot.jpg"
OUTPUT_GIF_SAVE_PATH = SAVE_PATH + "_sampling.gif.png"
OUTPUT_GIF_ONE_HOT_SAVE_PATH = SAVE_PATH + "_sampling_one-hot.gif.png"

current_datetime = datetime.datetime.now()
SAVE_PATH = f"images/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + '4-channels' if MULTI_CHANNEL else '1-channel'
FULL_MODEL_SAVE_PATH = f"models/trained_models/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + ('4-channels' if MULTI_CHANNEL else '1-channel') + "_trained-unet.pt"
FULL_MODEL_BEST_SAVE_PATH = f"models/trained_models/{current_datetime.strftime('%Y-%m-%d-%H-%M')}_" + ('4-channels' if MULTI_CHANNEL else '1-channel') + "_best-trained-unet.pt"


SAVE_PARAMS = {
    "IMAGE_SIZE": IMAGE_SIZE,
    "MULTI_CHANNEL": MULTI_CHANNEL,
    "BATCH_SIZE": BATCH_SIZE,
    "EPOCHS": EPOCHS,
    "T": T,
    "DIM_MULTS": DIM_MULTS
}

# %%
# Write parameters to the file
with open(PARAMS_SAVE_PATH, "w") as file:
    for key, value in SAVE_PARAMS.items():
        file.write(f"{key} = {value}\n")
print(f"Parameters saved to '{PARAMS_SAVE_PATH}'")
# Out:
# Parameters saved to 'models/trained_models/2024-12-17-14-53_4-channels_params.txt'

# %%
# Define the root data folder
root_data_folder = os.path.join(os.path.dirname(os.getcwd()), 'database')

# Define the sub path to the folders containing the data
data_sub_folders = {
    "train": "training",
    "test": "testing",
}

# Define the mapping from group labels to diagnostic classes
group_map = {
    "NOR": "Healthy control",
    "MINF": "Myocardial infarction",
    "DCM": "Dilated cardiomyopathy",
    "HCM": "Hypertrophic cardiomyopathy",
    "RV": "Abnormal right ventricle"
}

# %% [markdown]
# ## II. Data Loading and Displaying

# %%
#pip install ipywidgets
# Out:
# Collecting ipywidgetsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: colorama in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\louis\documents\prim\prim-ai-diffusion-models-for-cardiac-images-main\prim-ai-diffusion-models-for-cardiac-images-main\.conda\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
# Create a DataLoader instance
data_loader = DataLoader(root_data_folder)

# Load the data
for key, sub_folder in data_sub_folders.items():
    data_loader.load_data(sub_folder, name=key, store=True)
# Out:
# Loading data in 'c:\Users\louis\Documents\PRIM\PRIM-AI-Diffusion-Models-for-Cardiac-Images-main\PRIM-AI-Diffus…
# Loading data in 'c:\Users\louis\Documents\PRIM\PRIM-AI-Diffusion-Models-for-Cardiac-Images-main\PRIM-AI-Diffus…

# %%
# Initialize the DataDisplayer with the DataLoader instance
data_displayer = DataDisplayer(data_loader, group_map=group_map)

# %%
# Display as an arborescence the dataloader.data dictionary
print(data_displayer.display_data_arborescence('data_loader.data', max_keys={1: 2}))

# Display some examples
data_displayer.display_examples(nb_examples=1, per_combination=True, sort_by=('data_name', 'group', 'id'), format_sep=('#' * 90, '-' * 60, ''), format_categories=('{} data :\n', '{} :', '\n'))
# Out:
# data_loader.data
# ├── train
# │	├── patient001
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	├── patient002
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	├── ...
# ├── test
# │	├── patient101
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	├── patient102
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	├── ...
# ##########################################################################################
# test data :
# 	------------------------------------------------------------
# 	Dilated cardiomyopathy :
#
# 			ID: patient133, height: 185.0cm, weight: 121.0kg, group: DCM, nb_frames: 14
# 	------------------------------------------------------------
# 	Hypertrophic cardiomyopathy :
#
# 			ID: patient111, height: 172.0cm, weight: 80.0kg, group: HCM, nb_frames: 15
# 	------------------------------------------------------------
# 	Myocardial infarction :
#
# 			ID: patient135, height: 184.0cm, weight: 95.0kg, group: MINF, nb_frames: 20
# 	------------------------------------------------------------
# 	Healthy control :
#
# 			ID: patient144, height: 157.0cm, weight: 88.0kg, group: NOR, nb_frames: 25
# 	------------------------------------------------------------
# 	Abnormal right ventricle :
#
# 			ID: patient119, height: 162.0cm, weight: 60.0kg, group: RV, nb_frames: 15
# ##########################################################################################
# train data :
# 	------------------------------------------------------------
# 	Dilated cardiomyopathy :
#
# 			ID: patient008, height: 180.0cm, weight: 100.0kg, group: DCM, nb_frames: 28
# 	------------------------------------------------------------
# 	Hypertrophic cardiomyopathy :
#
# 			ID: patient024, height: 175.0cm, weight: 85.0kg, group: HCM, nb_frames: 28
# 	------------------------------------------------------------
# 	Myocardial infarction :
#
# 			ID: patient048, height: 167.0cm, weight: 73.0kg, group: MINF, nb_frames: 28
# 	------------------------------------------------------------
# 	Healthy control :
#
# 			ID: patient074, height: 175.0cm, weight: 87.0kg, group: NOR, nb_frames: 30
# 	------------------------------------------------------------
# 	Abnormal right ventricle :
#
# 			ID: patient086, height: 165.0cm, weight: 70.0kg, group: RV, nb_frames: 19

# %% [markdown]
# ## III. Data Overview

# %%
# Show repartition of shape of the images
shape_dict = {}
for dataset_key, dataset in data_loader.data.items():
    for patient, patient_data in dataset.items():
        for image_name, image in patient_data['image_data'].items():
            shape = image.shape
            if shape not in shape_dict:
                shape_dict[shape] = 1
            else:
                shape_dict[shape] += 1

print(
    f'There are {len(shape_dict)} different shapes in the data'
    f'\nX axis varies from {min([shape[0] for shape in shape_dict.keys()])} to {max([shape[0] for shape in shape_dict.keys()])}'
    f'\nY axis varies from {min([shape[1] for shape in shape_dict.keys()])} to {max([shape[1] for shape in shape_dict.keys()])}'
    f'\nZ axis varies from {min([shape[2] for shape in shape_dict.keys()])} to {max([shape[2] for shape in shape_dict.keys()])}'
    f'\nAspect ratio (X/Y) varies from {min([shape[0] / shape[1] for shape in shape_dict.keys()])} to {max([shape[0] / shape[1] for shape in shape_dict.keys()])}'
)
# plot the repartition of the aspect ratio
plt.figure(figsize=(10, 6))
plt.hist([shape[0] / shape[1] for shape in shape_dict.keys()], bins=20, color='skyblue', edgecolor='black')
plt.title('Aspect ratio distribution')
plt.xlabel('Aspect ratio (X/Y)')
plt.ylabel('Number of images')
plt.show()
# Out:
# There are 74 different shapes in the data
# X axis varies from 154 to 428
# Y axis varies from 154 to 512
# Z axis varies from 6 to 21
# Aspect ratio (X/Y) varies from 0.6388888888888888 to 1.4545454545454546

# %% [markdown]
# ## IV. Preprocessing

# %%
# Instanciate the data transformer
data_transformer = DataTransformer(data_loader)

# %%
# Resize the images to a common shape
target_shape = (IMAGE_SIZE, IMAGE_SIZE)
data_transformer.crop_and_resize(target_shape=target_shape, padding=0.2, output_key='image_resized_data', keep_3d_consistency=False, link_gt_to_data=False, create_channels_from_gt=MULTI_CHANNEL, image_names=['ED_gt', 'ES_gt'])

# Display tree of the data after resizing
print(data_displayer.display_data_arborescence('data_loader.data', max_keys=7))
# Out:
# Transforming images in 'train':   0%|          | 0/100 [00:00<?, ?it/s]
# Transforming images in 'test':   0%|          | 0/50 [00:00<?, ?it/s]
# data_loader.data
# ├── train
# │	├── patient093
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient077
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient099
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient038
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient032
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient045
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient064
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── ...
# ├── test
# │	├── patient125
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient117
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient141
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient136
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient104
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient103
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── patient109
# │	│	├── image_data
# │	│	│	├── ED
# │	│	│	├── ED_gt
# │	│	│	├── ES
# │	│	│	├── ES_gt
# │	│	├── height
# │	│	├── weight
# │	│	├── group
# │	│	├── nb_frames
# │	│	├── image_resized_data
# │	│	│	├── ED_gt
# │	│	│	├── ES_gt
# │	├── ...

# %%
# Display some examples for the resized images
data_displayer.display_examples(image_type='image_resized_data', image_names=['ED_gt', 'ES_gt'], nb_examples=1, per_combination=True, sort_by=('data_name', 'group', 'id'), format_sep=('#' * 90, '-' * 60, ''), format_categories=('{} data :\n', '{} :', '\n'))
# Out:
# ##########################################################################################
# test data :
# 	------------------------------------------------------------
# 	Dilated cardiomyopathy :
#
# 			ID: patient133, height: 185.0cm, weight: 121.0kg, group: DCM, nb_frames: 14
# 	------------------------------------------------------------
# 	Hypertrophic cardiomyopathy :
#
# 			ID: patient138, height: 174.0cm, weight: 90.0kg, group: HCM, nb_frames: 30
# 	------------------------------------------------------------
# 	Myocardial infarction :
#
# 			ID: patient148, height: 170.0cm, weight: 70.0kg, group: MINF, nb_frames: 35
# 	------------------------------------------------------------
# 	Healthy control :
#
# 			ID: patient150, height: 158.0cm, weight: 56.0kg, group: NOR, nb_frames: 30
# 	------------------------------------------------------------
# 	Abnormal right ventricle :
#
# 			ID: patient147, height: 172.0cm, weight: 104.0kg, group: RV, nb_frames: 19
# ##########################################################################################
# train data :
# 	------------------------------------------------------------
# 	Dilated cardiomyopathy :
#
# 			ID: patient014, height: 175.0cm, weight: 75.0kg, group: DCM, nb_frames: 30
# 	------------------------------------------------------------
# 	Hypertrophic cardiomyopathy :
#
# 			ID: patient024, height: 175.0cm, weight: 85.0kg, group: HCM, nb_frames: 28
# 	------------------------------------------------------------
# 	Myocardial infarction :
#
# 			ID: patient045, height: 174.0cm, weight: 68.0kg, group: MINF, nb_frames: 35
# 	------------------------------------------------------------
# 	Healthy control :
#
# 			ID: patient062, height: 172.0cm, weight: 74.0kg, group: NOR, nb_frames: 30
# 	------------------------------------------------------------
# 	Abnormal right ventricle :
#
# 			ID: patient088, height: 180.0cm, weight: 70.0kg, group: RV, nb_frames: 25

# %% [markdown]
# ## V. Data Augmentation

# %%
transformed_images_gt = data_loader.extract_specific_images(image_types=['image_resized_data'], image_names=['ED_gt', 'ES_gt'])
rotated_images = []
nb_rotations = 7
max_angle = 45
for angle in tqdm(np.linspace(-max_angle, max_angle, nb_rotations), desc='Rotating images'):
    if angle == 0:
        rotated_images.append(transformed_images_gt)
    else:
        rotated_images.append(DataTransformer.rotate_images(angle=angle, images=transformed_images_gt, has_channels=transformed_images_gt[0].shape[0] > 3))
# concatenate all lists
rotated_images = [images for sublist in rotated_images for images in sublist]
print(f'Number of images after rotation: {len(rotated_images)}')
# Out:
# Extracting images in 'train':   0%|          | 0/100 [00:00<?, ?it/s]
# Extracting images in 'test':   0%|          | 0/50 [00:00<?, ?it/s]
# Rotating images:   0%|          | 0/7 [00:00<?, ?it/s]
# Number of images after rotation: 2100

# %% [markdown]
# ## Model Diffusion Process

# %%
DEVICE = torch.device("cuda:1") if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Preprocessing

# %%
# Dataset parameters
batch_size = BATCH_SIZE

# %%
all_images = data_transformer.slice_depth_images(rotated_images)
# Keep a multiple of batch_size images
all_images = all_images[:(len(all_images)//batch_size)*batch_size]
all_images = DataTransformer.one_hot_encode_batch(all_images)
print(f'Number of images after slicing: {len(all_images)} ({len(all_images)//batch_size} batchs)')
# Out:
# Slicing images:   0%|          | 0/2100 [00:00<?, ?it/s]
# Number of images after slicing: 20832 (1302 batchs)

# %%
def normalize_dataset(images):
    flat_images = np.concatenate([img.flatten() for img in images])
    scaler = MinMaxScaler(feature_range=(-1., 1.))
    scaler.fit(flat_images.reshape(-1, 1))  # Fit on entire dataset
    return [scaler.transform(img.reshape(-1, 1)).reshape(img.shape) for img in images]
all_images = normalize_dataset(all_images)

# %%
train_size = batch_size * int((0.9 * len(all_images)//batch_size)//1)  # 90% for training
val_size = len(all_images) - train_size  # 10% for validation

print(f'{train_size} images ({train_size//batch_size} batchs) for train, {val_size} images ({val_size//batch_size} batchs) for validation. ({train_size/len(all_images):.0%}-{val_size/len(all_images):.0%})')
training_images, val_images = random_split(all_images, [train_size, val_size])
# Out:
# 18736 images (1171 batchs) for train, 2096 images (131 batchs) for validation. (90%-10%)

# %%
if LIBERATE_MEMORY:
    del shape_dict
    del data_loader
    del data_transformer
    del data_displayer
    del transformed_images_gt
    del rotated_images
    del all_images
    gc.collect()

# %%
train_dataloader, channels, image_size, len_dataloader = TorchDataLoader(dataset=training_images, batch_size=batch_size, shuffle=True), training_images[0].shape[0], target_shape[0], len(training_images)//batch_size

def format_batch_shape_string(batch_shape: tuple[int]):
    return "{} image(s), {} channel(s), {} row(s), {} column(s)".format(*batch_shape)

# Get a random batch from the train_dataloader without converting it to a list
random_batch_index = random.randint(0, len(train_dataloader) - 1)
# Use iter and advance to the random index
batch_iterator = iter(train_dataloader)
for _ in range(random_batch_index):
    next(batch_iterator)  # Advance to the random batch
batch_image = next(batch_iterator)  # Get the random batch
print(f"Shape of each batch: [{format_batch_shape_string(batch_image.shape)}]")
# Out:
# Shape of each batch: [16 image(s), 4 channel(s), 64 row(s), 64 column(s)]

# %%
def normalize_tensor_per_image(batch):
    # Normalize each image individually in the batch
    batch_normalized = torch.stack([2 * (image - image.min()) / (image.max() - image.min()) - 1 for image in batch])
    return batch_normalized

def show_images(batch, filename=None, one_hot_encode=False):
    image = np.array(torch.permute(make_grid(normalize_tensor_per_image(batch), nrow=int(np.sqrt(len(batch))), padding=0), (1,2,0)).cpu())
    image = (image + np.ones(image.shape))/2.
    if image.shape[-1] > 3:
        if one_hot_encode:
            image = DataDisplayer.one_hot_encode(image)
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))
        axes[0].imshow(image[..., 1:4])
        axes[0].set_title("RGB Channels")
        axes[0].axis('off')
        im_bg = axes[1].imshow(image[..., 0], cmap='viridis')
        axes[1].set_title("Background Intensity")
        axes[1].axis('off')
        cbar = fig.colorbar(im_bg, ax=axes[1], orientation='vertical', fraction=0.046, pad=0.04)
        cbar.set_label("Intensity")
        plt.tight_layout()
        if filename:
            fig.savefig(filename)
        plt.show()
    else:
        plt.imshow(image, cmap='gray')
        if filename:
            plt.savefig(filename)
        plt.show()

# %%
show_images(batch_image[:], INPUT_SAVE_PATH)
# Out:
# /tmp/ipykernel_2849016/300600383.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   image = np.array(torch.permute(make_grid(normalize_tensor_per_image(batch), nrow=int(np.sqrt(len(batch))), padding=0), (1,2,0)).cpu())

# %% [markdown]
# ## ControlNet Preprocessing

# %%
from acdcloader import *

data_dir = '/path/to/data/acdc'
image_size = 128
batch_size = 4
make_dimension_mask = True # 4 channels boolean mask
verbose = VerboseLevel.PRINT

# Create dataset and data loader
transform_train = partial(transform_image_and_mask, image_size=image_size, padding=0.1, make_dimension_mask=True)
ds = ACDCDataset(data_path=data_dir, transform=transform_train, mode='training', verbose=verbose)
data_loader = DataLoader(ds, batch_size=batch_size, shuffle=True)
data = iter(data_loader)

# Get next batch
images, masks, slice_ids = next(data)
print(f"images shape: {images.shape}")
print(f"masks shape: {masks.shape}")
print(f"slice_ids: {slice_ids}")

# %% [markdown]
# ## Forward Diffusion

# %% [markdown]
# ### Beta Scheduling

# %%
# Different type of beta schedule
def linear_beta_schedule(timesteps, beta_start = 0.0001, beta_end = 0.02):
    return torch.linspace(beta_start, beta_end, timesteps)

def cosine_beta_schedule(timesteps, s=0.008):
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * torch.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0.0001, 0.9999)

# %% [markdown]
# ### Constants calculation

# %%
# Function to get alphas and betas
def get_alph_bet(timesteps, schedule=cosine_beta_schedule):

    # define beta
    betas = schedule(timesteps)

    # define alphas
    alphas = 1. - betas
    alphas_cumprod = torch.cumprod(alphas, axis=0) # cumulative product of alpha
    alphas_cumprod_prev = F.pad(alphas_cumprod[:-1], (1, 0), value=1.0)  # corresponding to the prev const
    sqrt_recip_alphas = torch.sqrt(1.0 / alphas)

    # calculations for diffusion q(x_t | x_{t-1}) and others
    sqrt_alphas_cumprod = torch.sqrt(alphas_cumprod)
    sqrt_one_minus_alphas_cumprod = torch.sqrt(1. - alphas_cumprod)

    # calculations for posterior q(x_{t-1} | x_t, x_0)
    posterior_variance = betas * (1. - alphas_cumprod_prev) / (1. - alphas_cumprod)

    const_dict = {
        'betas': betas,
        'sqrt_recip_alphas': sqrt_recip_alphas,
        'sqrt_alphas_cumprod': sqrt_alphas_cumprod,
        'sqrt_one_minus_alphas_cumprod': sqrt_one_minus_alphas_cumprod,
        'posterior_variance': posterior_variance
    }

    return const_dict

# %% [markdown]
# ### Definition of $q(x_t | x_{0})$

# %%
# extract the values needed for time t
def extract(constants, batch_t, x_shape):
    diffusion_batch_size = batch_t.shape[0]

    # get a list of the appropriate constants of each timesteps
    out = constants.gather(-1, batch_t.cpu())

    return out.reshape(diffusion_batch_size, *((1,) * (len(x_shape) - 1))).to(batch_t.device)

# %%
# forward diffusion (using the nice property)
def q_sample(constants_dict, batch_x0, batch_t, noise=None):
    if noise is None:
        noise = torch.randn_like(batch_x0)

    sqrt_alphas_cumprod_t = extract(constants_dict['sqrt_alphas_cumprod'], batch_t, batch_x0.shape)
    sqrt_one_minus_alphas_cumprod_t = extract(
        constants_dict['sqrt_one_minus_alphas_cumprod'], batch_t, batch_x0.shape
    )

    return sqrt_alphas_cumprod_t * batch_x0 + sqrt_one_minus_alphas_cumprod_t * noise

# %%
const_linear_dict = get_alph_bet(T, schedule=linear_beta_schedule)
const_cosine_dict = get_alph_bet(T, schedule=cosine_beta_schedule)

batch_t = torch.arange(batch_size)*(T//batch_size)  # get a range of timesteps from 0 to T
print(f"timesteps: {batch_t}")
noisy_batch_linear = q_sample(const_linear_dict, batch_image, batch_t, noise=None)
noisy_batch_cosine = q_sample(const_cosine_dict, batch_image, batch_t, noise=None)

print("Original images:")
show_images(batch_image[:])

print("Noised images with linear shedule:")
show_images(noisy_batch_linear[:])

print("Noised images with cosine shedule:")
show_images(noisy_batch_cosine[:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 const_linear_dict = get_alph_bet(T, schedule=linear_beta_schedule)
#       2 const_cosine_dict = get_alph_bet(T, schedule=cosine_beta_schedule)
#       4 batch_t = torch.arange(batch_size)*(T//batch_size)  # get a range of timesteps from 0 to T
#
# NameError: name 'get_alph_bet' is not defined

# %% [markdown]
# ## Model Diffusion Process

# %% [markdown]
# ### Model definition

# %%
model = Unet(
        dim=image_size,
        init_dim=None,
        out_dim=None,
        dim_mults=DIM_MULTS,
        channels=channels,
        with_time_emb=True,
        convnext_mult=2,
    ).to(DEVICE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = Unet(
#       2         dim=image_size,
#       3         init_dim=None,
#       4         out_dim=None,
#       5         dim_mults=DIM_MULTS,
#       6         channels=channels,
#       7         with_time_emb=True,
#       8         convnext_mult=2,
#       9     ).to(DEVICE)
#
# NameError: name 'Unet' is not defined

# %% [markdown]
# ### Definition of $ p_{\theta}(x_{t-1}|x_t) $

# %%
@torch.no_grad()
def p_sample(constants_dict, batch_xt, predicted_noise, batch_t):
    # We first get every constants needed and send them in right device
    betas_t = extract(constants_dict['betas'], batch_t, batch_xt.shape).to(batch_xt.device)
    sqrt_one_minus_alphas_cumprod_t = extract(
        constants_dict['sqrt_one_minus_alphas_cumprod'], batch_t, batch_xt.shape
    ).to(batch_xt.device)
    sqrt_recip_alphas_t = extract(
        constants_dict['sqrt_recip_alphas'], batch_t, batch_xt.shape
    ).to(batch_xt.device)

    # Equation 11 in the ddpm paper
    # Use predicted noise to predict the mean (mu theta)
    model_mean = sqrt_recip_alphas_t * (
        batch_xt - betas_t * predicted_noise / sqrt_one_minus_alphas_cumprod_t
    )

    # We have to be careful to not add noise if we want to predict the final image
    predicted_image = torch.zeros(batch_xt.shape).to(batch_xt.device)
    t_zero_index = (batch_t == torch.zeros(batch_t.shape).to(batch_xt.device))

    # Algorithm 2 line 4, we add noise when timestep is not 1:
    posterior_variance_t = extract(constants_dict['posterior_variance'], batch_t, batch_xt.shape)
    noise = torch.randn_like(batch_xt)  # create noise, same shape as batch_x
    predicted_image[~t_zero_index] = model_mean[~t_zero_index] + (
        torch.sqrt(posterior_variance_t[~t_zero_index]) * noise[~t_zero_index]
    )

    # If t=1 we don't add noise to mu
    predicted_image[t_zero_index] = model_mean[t_zero_index]

    return predicted_image

# %% [markdown]
# ## Sampling

# %% [markdown]
# # - être sûr que c'est bien les images segmentées dont on gère la diffusion et que les images non segmentées et non bruitées n'interviennent qu'au bon moment

# %%
# Algorithm 2 (including returning all images)
@torch.no_grad()
def sampling(model, shape, T, constants_dict):
    b = shape[0]
    # start from pure noise (for each example in the batch)
    batch_xt = torch.randn(shape, device=DEVICE)

    batch_t = torch.ones(shape[0]) * T  # create a vector with batch-size time the timestep
    batch_t = batch_t.type(torch.int64).to(DEVICE)

    imgs = []

    for t in tqdm(reversed(range(0, T)), desc='sampling loop time step', total=T):
        batch_t -= 1
        predicted_noise = model(batch_xt, batch_t)

        batch_xt = p_sample(constants_dict, batch_xt, predicted_noise, batch_t)

        imgs.append(batch_xt.cpu())

    return imgs

# %% [markdown]
# ## Training

# %%
train_dataloader, channels, image_size, len_dataloader = TorchDataLoader(dataset=training_images, batch_size=batch_size, shuffle=True), training_images[0].shape[0], target_shape[0], len(training_images)//batch_size
constants_dict = get_alph_bet(T, schedule=linear_beta_schedule)

val_dataloader = TorchDataLoader(val_images, batch_size=batch_size, shuffle=False)

epochs = EPOCHS

learning_rate=1e-4

criterion = nn.SmoothL1Loss()
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ### Training ControlNet

# %%
"""  
def configure_optimizers(self):      ## Handles the locked U-NET part ??? (if not locked then add the parameters to the updating schedule)
        lr = self.learning_rate          ## If this is true, then these locked params are stored at model.diffusion_model.output_blocks.parameters() and at 
        params = list(self.control_model.parameters())   ## model.diffusion_model.out.parameters() which I have to check out
        if not self.sd_locked:            ## And also the parameters are control_model.parameters() which are different from self.model or self.cond_stage_model
            params += list(self.model.diffusion_model.output_blocks.parameters()) ## or self.first_stage_model
            params += list(self.model.diffusion_model.out.parameters())
        opt = torch.optim.AdamW(params, lr=lr)
        return opt
"""
from util import *

from ControledUNet import ControlledUnetModel

from ControlNet import ControlNET

#from acdcloader import *

from Full_Model import *


## Main model for which the forward will be the step
controlledunetmodel = ControlledUnetModel(
        dim=image_size,
        init_dim=None,
        out_dim=None,
        dim_mults=DIM_MULTS,
        channels=channels,
        with_time_emb=True,
        convnext_mult=2,
    ).to(DEVICE)

controlledunetmodel.load_state_dict(torch.load(MODEL_LOAD_PATH, weights_only=True, map_location=torch.device(DEVICE)))
controlledunetmodel.eval()

## Model for which the forward will be given as argument to 
##controlledunetmodel
controlnet = ControlNET(
        dim=image_size,
        init_dim=None,
        out_dim=None,
        dim_mults=DIM_MULTS,
        channels=channels,
        with_time_emb=True,
        convnext_mult=2,
    ).to(DEVICE)

controlnet.load_state_dict(torch.load(MODEL_LOAD_PATH, weights_only=True, map_location=torch.device(DEVICE)))
controlnet.eval()

full_model = Full_Model(
       controlledunetmodel, controlnet
       
    ).to(DEVICE)


"""
def apply_model(self, x_noisy, t, cond, *args, **kwargs):
        assert isinstance(cond, dict)
        diffusion_model = self.model.diffusion_model


        if cond is None:
            eps = diffusion_model(x=x_noisy, timesteps=t, control=None)
            
        else:
            control = controlnet(x=x_noisy, hint=torch.cat(cond['c_concat'], 1), timesteps=t)
            control = [c * scale for c, scale in zip(control, self.control_scales)]
            eps = diffusion_model(x=x_noisy, timesteps=t, control=control)



        return eps
"""

"""
def apply_forward_full_model(x,hint, time):
      control_output = controlnet(x,hint,time)
      full_model_output = controlledunetmodel(x,time,control_output)
      return full_model_output
"""

def configure_optimizers():      ## Handles the locked U-NET part ??? (if not locked then add the parameters to the updating schedule)
        lr = learning_rate         ## If this is true, then these locked params are stored at model.diffusion_model.output_blocks.parameters() and at 
        params = list(full_model.controlnet.parameters())   ## model.diffusion_model.out.parameters() which I have to check out
        

        excluded_params = set(id(p) for p in full_model.controlnet.ups.parameters())  # Get IDs of upsample parameters
        params_to_optimize = [p for p in model.parameters() if id(p) not in excluded_params]

        ## Enfait ici comme la partie up n'est pas utilisée dans le 
        ## forward et bien elle ne va pas être utilisée non ?

        # Define optimizer with the filtered parameters
        
        """
        if not self.sd_locked:            ## And also the parameters are control_model.parameters() which are different from self.model or self.cond_stage_model
            params += list(self.model.diffusion_model.output_blocks.parameters()) ## or self.first_stage_model
            params += list(self.model.diffusion_model.out.parameters())
        
        """
        

        optimizer = Adam(params_to_optimize, lr=1e-4)

        
        return optimizer

optimizer = configure_optimizers()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 13
#       1 """
#       2 def configure_optimizers(self):      ## Handles the locked U-NET part ??? (if not locked then add the parameters to the updating schedule)
#       3         lr = self.learning_rate          ## If this is true, then these locked params are stored at model.diffusion_model.output_blocks.parameters() and at
#    (...)
#       9         return opt
#      10 """
#      11 import util
# ---> 13 import ControlledUnetModel
#      15 import ControlNET
#      17 import acdcloader
#
# ModuleNotFoundError: No module named 'ControlledUnetModel'

# %% [markdown]
# # Training Loop for ControlNet

# %%
if TRAIN_FULL_MODEL:
    best_val_loss = float('inf')  # Start with an infinitely high loss
    best_model_state = None  # To save the best model
    last_model_state = None  # To save the last model
    best_epoch = 0

    train_losses = np.zeros(epochs)
    val_losses = np.zeros(epochs)

    # Create a fixed `T_val_steps` for validation (choose a specific time step range you want for validation)
    T_val_steps = torch.randint(0, T, (batch_size,), device=DEVICE).long()  # fixed time steps for validation
    
    for epoch in range(epochs):
        Full_Model.train()
        train_loss = 0.0
        loop = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{epochs}")
        for batch in loop:
            optimizer.zero_grad()

            batch_size_iter = batch.shape[0]
            batch_image = batch.to(DEVICE)
            batch_image = normalize_tensor_per_image(batch_image)
            """à définir batch_hint
            """
            batch_hint = []

            # Algorithm 1 line 3: sample t uniformally for every example in the batch
            batch_t = torch.randint(0, T, (batch_size_iter,), device=DEVICE).long()

            noise = torch.randn_like(batch_image)

            x_noisy = q_sample(constants_dict, batch_image, batch_t, noise=noise)

           
            predicted_noise = Full_Model(x_noisy, batch_hint, batch_t)

            loss = criterion(noise, predicted_noise)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            loop.set_postfix(loss=loss.item())
        train_losses[epoch] = train_loss /len(train_dataloader)

        # After the training loop, calculate validation loss using fixed `T_val_steps`
        Full_Model.eval()  # Set the model to evaluation mode
        val_loss = 0.0
        with torch.no_grad():  # Don't compute gradients for validation
            for batch in val_dataloader:
                batch_image = batch.to(DEVICE)
    
                # Use the fixed `T_val_steps` for validation (the same time steps across all validation batches)
                batch_t = T_val_steps  # Fixed time steps for validation
    
                noise = torch.randn_like(batch_image)
    
                # Forward pass through the model
                x_noisy = q_sample(constants_dict, batch_image, batch_t, noise=noise)
                predicted_noise = Full_Model(x_noisy, batch_t)
    
                # Compute the validation loss
                loss = criterion(noise, predicted_noise)
                val_loss += loss.item()
    
        val_loss /= len(val_dataloader)
        val_losses[epoch] = val_loss
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[epoch]:.4f}, Validation Loss: {val_losses[epoch]:.4f}")
    
        # Save the best model (with the lowest validation loss)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_full_model_state = Full_Model.state_dict()  # Save the best model's state
            best_epoch = epoch

    # Save the last model (after the final epoch)
    last_full_model_state = Full_Model.state_dict()

    # After training, plot the train and validation losses
    plt.figure(figsize=(10, 6))
    plt.plot(range(epochs), train_losses, label='Train Loss', color='blue')
    plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.savefig(OUTPUT_LOSS_MONITORING_PATH)
    plt.show()

    if SAVE_FULL_MODEL:
        torch.save(last_full_model_state, FULL_MODEL_SAVE_PATH)
        if best_epoch < epochs - 1:
            torch.save(best_full_model_state, FULL_MODEL_BEST_SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 if TRAIN_FULL_MODEL:
#       2     best_val_loss = float('inf')  # Start with an infinitely high loss
#       3     best_model_state = None  # To save the best model
#
# NameError: name 'TRAIN_FULL_MODEL' is not defined

# %% [markdown]
# ### Training loop

# %%
"""
if TRAIN_MODEL:
    best_val_loss = float('inf')  # Start with an infinitely high loss
    best_model_state = None  # To save the best model
    last_model_state = None  # To save the last model
    best_epoch = 0

    train_losses = np.zeros(epochs)
    val_losses = np.zeros(epochs)

    # Create a fixed `T_val_steps` for validation (choose a specific time step range you want for validation)
    T_val_steps = torch.randint(0, T, (batch_size,), device=DEVICE).long()  # fixed time steps for validation
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        loop = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{epochs}")
        for batch in loop:
            optimizer.zero_grad()

            batch_size_iter = batch.shape[0]
            batch_image = batch.to(DEVICE)
            batch_image = normalize_tensor_per_image(batch_image)

            # Algorithm 1 line 3: sample t uniformally for every example in the batch
            batch_t = torch.randint(0, T, (batch_size_iter,), device=DEVICE).long()

            noise = torch.randn_like(batch_image)

            x_noisy = q_sample(constants_dict, batch_image, batch_t, noise=noise)
            predicted_noise = model(x_noisy, batch_t)

            loss = criterion(noise, predicted_noise)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            loop.set_postfix(loss=loss.item())
        train_losses[epoch] = train_loss /len(train_dataloader)

        # After the training loop, calculate validation loss using fixed `T_val_steps`
        model.eval()  # Set the model to evaluation mode
        val_loss = 0.0
        with torch.no_grad():  # Don't compute gradients for validation
            for batch in val_dataloader:
                batch_image = batch.to(DEVICE)
    
                # Use the fixed `T_val_steps` for validation (the same time steps across all validation batches)
                batch_t = T_val_steps  # Fixed time steps for validation
    
                noise = torch.randn_like(batch_image)
    
                # Forward pass through the model
                x_noisy = q_sample(constants_dict, batch_image, batch_t, noise=noise)
                predicted_noise = model(x_noisy, batch_t)
    
                # Compute the validation loss
                loss = criterion(noise, predicted_noise)
                val_loss += loss.item()
    
        val_loss /= len(val_dataloader)
        val_losses[epoch] = val_loss
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[epoch]:.4f}, Validation Loss: {val_losses[epoch]:.4f}")
    
        # Save the best model (with the lowest validation loss)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()  # Save the best model's state
            best_epoch = epoch

    # Save the last model (after the final epoch)
    last_model_state = model.state_dict()

    # After training, plot the train and validation losses
    plt.figure(figsize=(10, 6))
    plt.plot(range(epochs), train_losses, label='Train Loss', color='blue')
    plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.savefig(OUTPUT_LOSS_MONITORING_PATH)
    plt.show()

    if SAVE_MODEL:
        torch.save(last_model_state, MODEL_SAVE_PATH)
        if best_epoch < epochs - 1:
            torch.save(best_model_state, MODEL_BEST_SAVE_PATH)

"""
# Out:
# Epoch 1/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 1/100, Train Loss: 0.0927, Validation Loss: 0.0283
# Epoch 2/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 2/100, Train Loss: 0.0240, Validation Loss: 0.0115
# Epoch 3/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 3/100, Train Loss: 0.0142, Validation Loss: 0.0076
# Epoch 4/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 4/100, Train Loss: 0.0108, Validation Loss: 0.0067
# Epoch 5/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 5/100, Train Loss: 0.0087, Validation Loss: 0.0048
# Epoch 6/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 6/100, Train Loss: 0.0071, Validation Loss: 0.0041
# Epoch 7/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 7/100, Train Loss: 0.0063, Validation Loss: 0.0041
# Epoch 8/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 8/100, Train Loss: 0.0052, Validation Loss: 0.0032
# Epoch 9/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 9/100, Train Loss: 0.0047, Validation Loss: 0.0030
# Epoch 10/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 10/100, Train Loss: 0.0042, Validation Loss: 0.0033
# Epoch 11/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 11/100, Train Loss: 0.0040, Validation Loss: 0.0028
# Epoch 12/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 12/100, Train Loss: 0.0033, Validation Loss: 0.0023
# Epoch 13/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 13/100, Train Loss: 0.0033, Validation Loss: 0.0022
# Epoch 14/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 14/100, Train Loss: 0.0031, Validation Loss: 0.0023
# Epoch 15/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 15/100, Train Loss: 0.0028, Validation Loss: 0.0020
# Epoch 16/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 16/100, Train Loss: 0.0030, Validation Loss: 0.0023
# Epoch 17/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 17/100, Train Loss: 0.0025, Validation Loss: 0.0018
# Epoch 18/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 18/100, Train Loss: 0.0026, Validation Loss: 0.0020
# Epoch 19/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 19/100, Train Loss: 0.0026, Validation Loss: 0.0018
# Epoch 20/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 20/100, Train Loss: 0.0024, Validation Loss: 0.0017
# Epoch 21/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 21/100, Train Loss: 0.0023, Validation Loss: 0.0017
# Epoch 22/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 22/100, Train Loss: 0.0022, Validation Loss: 0.0017
# Epoch 23/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 23/100, Train Loss: 0.0022, Validation Loss: 0.0020
# Epoch 24/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 24/100, Train Loss: 0.0022, Validation Loss: 0.0014
# Epoch 25/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 25/100, Train Loss: 0.0021, Validation Loss: 0.0014
# Epoch 26/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 26/100, Train Loss: 0.0020, Validation Loss: 0.0016
# Epoch 27/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 27/100, Train Loss: 0.0023, Validation Loss: 0.0020
# Epoch 28/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 28/100, Train Loss: 0.0021, Validation Loss: 0.0015
# Epoch 29/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 29/100, Train Loss: 0.0018, Validation Loss: 0.0017
# Epoch 30/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 30/100, Train Loss: 0.0021, Validation Loss: 0.0019
# Epoch 31/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 31/100, Train Loss: 0.0018, Validation Loss: 0.0014
# Epoch 32/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 32/100, Train Loss: 0.0017, Validation Loss: 0.0013
# Epoch 33/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 33/100, Train Loss: 0.0019, Validation Loss: 0.0018
# Epoch 34/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 34/100, Train Loss: 0.0018, Validation Loss: 0.0013
# Epoch 35/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 35/100, Train Loss: 0.0017, Validation Loss: 0.0015
# Epoch 36/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 36/100, Train Loss: 0.0018, Validation Loss: 0.0014
# Epoch 37/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 37/100, Train Loss: 0.0017, Validation Loss: 0.0015
# Epoch 38/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 38/100, Train Loss: 0.0017, Validation Loss: 0.0013
# Epoch 39/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 39/100, Train Loss: 0.0018, Validation Loss: 0.0014
# Epoch 40/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 40/100, Train Loss: 0.0016, Validation Loss: 0.0013
# Epoch 41/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 41/100, Train Loss: 0.0019, Validation Loss: 0.0013
# Epoch 42/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 42/100, Train Loss: 0.0016, Validation Loss: 0.0018
# Epoch 43/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 43/100, Train Loss: 0.0017, Validation Loss: 0.0013
# Epoch 44/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 44/100, Train Loss: 0.0015, Validation Loss: 0.0013
# Epoch 45/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 45/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 46/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 46/100, Train Loss: 0.0016, Validation Loss: 0.0012
# Epoch 47/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 47/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 48/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 48/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 49/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 49/100, Train Loss: 0.0016, Validation Loss: 0.0012
# Epoch 50/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 50/100, Train Loss: 0.0016, Validation Loss: 0.0025
# Epoch 51/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 51/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 52/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 52/100, Train Loss: 0.0017, Validation Loss: 0.0014
# Epoch 53/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 53/100, Train Loss: 0.0014, Validation Loss: 0.0012
# Epoch 54/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 54/100, Train Loss: 0.0016, Validation Loss: 0.0012
# Epoch 55/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 55/100, Train Loss: 0.0014, Validation Loss: 0.0011
# Epoch 56/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 56/100, Train Loss: 0.0014, Validation Loss: 0.0012
# Epoch 57/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 57/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 58/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 58/100, Train Loss: 0.0015, Validation Loss: 0.0012
# Epoch 59/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 59/100, Train Loss: 0.0014, Validation Loss: 0.0015
# Epoch 60/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 60/100, Train Loss: 0.0015, Validation Loss: 0.0011
# Epoch 61/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 61/100, Train Loss: 0.0015, Validation Loss: 0.0014
# Epoch 62/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 62/100, Train Loss: 0.0014, Validation Loss: 0.0012
# Epoch 63/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 63/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 64/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 64/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 65/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 65/100, Train Loss: 0.0015, Validation Loss: 0.0011
# Epoch 66/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 66/100, Train Loss: 0.0013, Validation Loss: 0.0012
# Epoch 67/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 67/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 68/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 68/100, Train Loss: 0.0016, Validation Loss: 0.0012
# Epoch 69/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 69/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 70/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 70/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 71/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 71/100, Train Loss: 0.0014, Validation Loss: 0.0011
# Epoch 72/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 72/100, Train Loss: 0.0012, Validation Loss: 0.0011
# Epoch 73/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 73/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 74/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 74/100, Train Loss: 0.0014, Validation Loss: 0.0011
# Epoch 75/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 75/100, Train Loss: 0.0014, Validation Loss: 0.0011
# Epoch 76/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 76/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 77/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 77/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 78/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 78/100, Train Loss: 0.0013, Validation Loss: 0.0010
# Epoch 79/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 79/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 80/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 80/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 81/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 81/100, Train Loss: 0.0012, Validation Loss: 0.0011
# Epoch 82/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 82/100, Train Loss: 0.0014, Validation Loss: 0.0013
# Epoch 83/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 83/100, Train Loss: 0.0012, Validation Loss: 0.0012
# Epoch 84/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 84/100, Train Loss: 0.0012, Validation Loss: 0.0011
# Epoch 85/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 85/100, Train Loss: 0.0013, Validation Loss: 0.0011
# Epoch 86/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 86/100, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 87/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 87/100, Train Loss: 0.0013, Validation Loss: 0.0010
# Epoch 88/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 88/100, Train Loss: 0.0013, Validation Loss: 0.0012
# Epoch 89/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 89/100, Train Loss: 0.0012, Validation Loss: 0.0011
# Epoch 90/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 90/100, Train Loss: 0.0012, Validation Loss: 0.0012
# Epoch 91/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 91/100, Train Loss: 0.0013, Validation Loss: 0.0010
# Epoch 92/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 92/100, Train Loss: 0.0012, Validation Loss: 0.0011
# Epoch 93/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 93/100, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 94/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 94/100, Train Loss: 0.0013, Validation Loss: 0.0010
# Epoch 95/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 95/100, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 96/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 96/100, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 97/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 97/100, Train Loss: 0.0013, Validation Loss: 0.0010
# Epoch 98/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 98/100, Train Loss: 0.0011, Validation Loss: 0.0011
# Epoch 99/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 99/100, Train Loss: 0.0012, Validation Loss: 0.0010
# Epoch 100/100:   0%|          | 0/1171 [00:00<?, ?it/s]
# Epoch 100/100, Train Loss: 0.0012, Validation Loss: 0.0010

# %%
print(f"Best epoch : {best_epoch}, validation loss : {val_losses[best_epoch]:.4f}")
# Out:
# Best epoch : 98, validation loss : 0.0010

# %% [markdown]
# ## Reload model

# %%
if LOAD_MODEL :
    model = Unet(
            dim=image_size,
            init_dim=None,
            out_dim=None,
            dim_mults=DIM_MULTS,
            channels=channels,
            with_time_emb=True,
            convnext_mult=2,
        ).to(DEVICE)
    model.load_state_dict(torch.load(MODEL_LOAD_PATH, weights_only=True, map_location=torch.device(DEVICE)))
    model.eval()

# %% [markdown]
# ## Reload Control model (full_model)

# %%
if LOAD_MODEL :
    controlledunetmodel = ControlledUnetModel(
        dim=image_size,
        init_dim=None,
        out_dim=None,
        dim_mults=DIM_MULTS,
        channels=channels,
        with_time_emb=True,
        convnext_mult=2,
    ).to(DEVICE)

    ## Model for which the forward will be given as argument to 
    ##controlledunetmodel
    controlnet = ControlNET(
            dim=image_size,
            init_dim=None,
            out_dim=None,
            dim_mults=DIM_MULTS,
            channels=channels,
            with_time_emb=True,
            convnext_mult=2,
        ).to(DEVICE)

    full_model = Full_Model(
        controlledunetmodel, controlnet
    )
        
    full_model.load_state_dict(torch.load(FULL_MODEL_LOAD_PATH, weights_only=True, map_location=torch.device(DEVICE)))
    full_model.eval()

# %% [markdown]
# ## View of the controlNet (full_model) diffusion process towards segmentation and segmentation results (IOU and Others ?)

# %% [markdown]
# ## View of the diffusion process

# %%
def make_gif(frame_list, filename, step=5, one_hot_encode=True):    
    to_pil = ToPILImage()
    
    frames = [np.array(torch.permute(make_grid(normalize_tensor_per_image(tens_im), nrow=int(np.sqrt(batch_size))), (1,2,0)).cpu()) for tens_im in frame_list]
    frames_to_include = frames[0] + frames[1::step]
    if frames[-1] not in frames_to_include:
        frames_to_include.append(frames[-1])
    if frames_to_include[0].shape[-1] > 3:
        if one_hot_encode:
            frames_to_include = [DataDisplayer.one_hot_encode(frame) for frame in frames_to_include]
        frames_to_include = [frame[..., 1:4] for frame in frames_to_include]
    frames_pil = [to_pil(frame) for frame in frames_to_include]
    frame_one = frames_pil[0]
    
    frame_one.save(filename, format="GIF", append_images=frames_pil[1::], save_all=True, duration=10, loop=0)

    return IPython.display.Image(filename=filename)

# %%
print("check generation:")
list_gen_imgs = sampling(model, (batch_size, channels, image_size, image_size), T, constants_dict)
show_images(list_gen_imgs[-1][:], OUTPUT_SAVE_PATH, one_hot_encode=False)
show_images(list_gen_imgs[-1][:], OUTPUT_ONE_HOT_SAVE_PATH, one_hot_encode=True)
# Out:
# check generation:
# sampling loop time step:   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_2849016/300600383.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   image = np.array(torch.permute(make_grid(normalize_tensor_per_image(batch), nrow=int(np.sqrt(len(batch))), padding=0), (1,2,0)).cpu())
# /tmp/ipykernel_2849016/300600383.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   image = np.array(torch.permute(make_grid(normalize_tensor_per_image(batch), nrow=int(np.sqrt(len(batch))), padding=0), (1,2,0)).cpu())

# %%
display(make_gif(list_gen_imgs, OUTPUT_GIF_ONE_HOT_SAVE_PATH, step=20))
display(make_gif(list_gen_imgs, OUTPUT_GIF_SAVE_PATH, step=20))
# Out:
# /tmp/ipykernel_2849016/2522349631.py:4: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   frames = [np.array(torch.permute(make_grid(normalize_tensor_per_image(tens_im), nrow=int(np.sqrt(batch_size))), (1,2,0)).cpu()) for tens_im in frame_list]

# %%
'''
generated_images = []
for _ in tqdm(range(100), desc='Generating images'):
    sample = sampling(model, (batch_size, channels, image_size, image_size), T, constants_dict)
    for image in sample[-1][:]:
        generated_images.append(image)
'''
# Out:
# "\ngenerated_images = []\nfor _ in tqdm(range(100), desc='Generating images'):\n    sample = sampling(model, (batch_size, channels, image_size, image_size), T, constants_dict)\n    for image in sample[-1][:]:\n        generated_images.append(image)\n"
